# %%
import os
os.chdir("..")  # Move up from notebooks/ to project root
print(os.getcwd())  # Should print C:\Projects\AI_QUESTION_GENERATOR
# Out:
# c:\Projects\AI_QUESTION_GENERATOR

# %%
import sys
import os
sys.path.append(os.path.abspath("."))  # Adds project root to Python path

# %%
import sys
print(sys.executable)
# Out:
# c:\Projects\AI_QUESTION_GENERATOR\.venv\Scripts\python.exe

# %%
from model.question_handler import QuestionHandler
from model.document_generator import DocumentGenerator

# %%
from model.question_handler import QuestionHandler
from model.document_generator import DocumentGenerator

# Initialize objects
qh = QuestionHandler()
dg = DocumentGenerator()
